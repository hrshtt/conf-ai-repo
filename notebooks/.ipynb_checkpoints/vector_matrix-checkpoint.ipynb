# %%
import numpy as np

# %%
vector_matrix = np.loadtxt('../data/vectors/vector_matrix.npz')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f7770c3b7f34> in <module>
# ----> 1 vector_matrix = np.loadtxt('../data/vectors/vector_matrix.npz')
#
# ~/Documents/Code/w-akash/AI-Cull-Duplicates/ml_env/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1157         # converting the data
#    1158         X = None
# -> 1159         for x in read_data(_loadtxt_chunksize):
#    1160             if X is None:
#    1161                 X = np.array(x, dtype)
#
# ~/Documents/Code/w-akash/AI-Cull-Duplicates/ml_env/lib/python3.8/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1085
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
# ...
